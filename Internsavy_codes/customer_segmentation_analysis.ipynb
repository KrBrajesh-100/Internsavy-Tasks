# %% [markdown]
# Importing the libraries which required

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# reading or uploading the data

# %%
data = pd.read_csv('/content/Mall_Customers.csv')

# %%
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# Cleaning the data

# %%
data.isna().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %% [markdown]
# Segmenting the Customer data by visualizing graph based on different parameters

# %% [markdown]
# In below graph, we clearly see that fermales are more than males

# %%
sns.countplot(x='Gender',data=data)
plt.title('Distribution of Gender')
# Out:
# Text(0.5, 1.0, 'Distribution of Gender')

# %% [markdown]
# In thid graph, we clearly see that between 30-40 yr of age have high number of population

# %%
data.hist('Age',bins=40)
plt.title('Distribution of age')
plt.xlabel('age')
# Out:
# Text(0.5, 0, 'age')

# %% [markdown]
# In this graph, we clearly see that at between 30-40 yr of age there is large number of females than males

# %%
plt.hist('Age',data = data[data['Gender']=='Male'],alpha=0.5,label='Male')
plt.hist('Age',data = data[data['Gender']=='Female'],alpha=0.5,label='Female')
plt.title('Distribution of age by gender')
plt.xlabel('Age')
plt.legend()

# %% [markdown]
# In this graph, there is between 60-80k have highest number of counts

# %%
data.hist('Annual Income (k$)')
plt.title('Annual Income Distribution in Thousands of Dollars')
plt.xlabel('Thousand of Dollars')
# Out:
# Text(0.5, 0, 'Thousand of Dollars')

# %% [markdown]
# In this graph, we clearly see that females have high income

# %%
plt.hist('Annual Income (k$)',data = data[data['Gender']=='Male'],alpha=0.5,label='Male')
plt.hist('Annual Income (k$)',data = data[data['Gender']=='Female'],alpha=0.5,label='Female')
plt.title('Distribution of income by gender')
plt.xlabel('Thousand of Dollars')
plt.legend()

# %% [markdown]
# mean of male and female customers based on their spending

# %%
Male_customers = data[data['Gender']=='Male']
Female_customers = data[data['Gender']=='Female']

print(Male_customers['Spending Score (1-100)'].mean())
print(Female_customers['Spending Score (1-100)'].mean())
# Out:
# 48.51136363636363
# 51.526785714285715

# %% [markdown]
# Heatmap for seeing the correlation between various variables:

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <ipython-input-22-6c71ac866e2e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <Axes: >

# %% [markdown]
# Heatmap for female_customers

# %%
sns.heatmap(Female_customers.corr(),annot=True)
plt.title('Correlation heatmap - Female')
# Out:
# <ipython-input-29-8f27dceff7c6>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(Female_customers.corr(),annot=True)
# Text(0.5, 1.0, 'Correlation heatmap - Female')

# %% [markdown]
# Heatmap for male_customers

# %%
sns.heatmap(Male_customers.corr(),annot=True)
plt.title('Correlation heatmap - Male')
# Out:
# <ipython-input-30-8a9ef716ea4d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(Male_customers.corr(),annot=True)
# Text(0.5, 1.0, 'Correlation heatmap - Male')

# %% [markdown]
# As from above all I conclude that females have the highest income and spending more than males and senior males have low spending habits
